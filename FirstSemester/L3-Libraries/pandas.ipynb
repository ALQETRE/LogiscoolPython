# %%
import pandas as pd

# %%
data = {
    "Name": ["Alan", "Bob", "Clara", "Dave"],
    "Age": [21, 10, 68, 13],
    "English": [True, False, False, True],
    "Place": ["Dejvice", "Smíchov", "Holešovice", "Barandov"],
    "Score": [100, 200, 150, 50]
}

df = pd.DataFrame(data, index= ["A", "B", "C", "D"])

df # <- Pokud používáme JupiterNotebook, tak můžeme jen napsat co chceme vytisknout
# Out:
#     Name  Age  English       Place  Score
# A   Alan   21     True     Dejvice    100
# B    Bob   10    False     Smíchov    200
# C  Clara   68    False  Holešovice    150
# D   Dave   13     True    Barandov     50

# %%
# Chceme získat pouze jména
# + jména a věk

df.loc[:, "Name"] # or df.loc[ :, ["Name", "Age"] ]
# Out:
# A     Alan
# B      Bob
# C    Clara
# D     Dave
# Name: Name, dtype: object

# %%
df["Name"]
# Out:
# A     Alan
# B      Bob
# C    Clara
# D     Dave
# Name: Name, dtype: object

# %%
# Chceme získat místo na řádku C
# + na řádku C a D

df.loc[["C", "D"], "Place"]
# Out:
# C    Holešovice
# D      Barandov
# Name: Place, dtype: object

# %%
# Pouze řádky 1 a 2 

df.iloc[[1, 2]]
# Out:
#     Name  Age  English       Place  Score
# B    Bob   10    False     Smíchov    200
# C  Clara   68    False  Holešovice    150

# %%
# Ukázat jenom řádky 1 a 2, ale za použití bool

df.loc[ [False, True, True, False] ]
# Out:
#     Name  Age  English       Place  Score
# B    Bob   10    False     Smíchov    200
# C  Clara   68    False  Holešovice    150

# %%
# Vytisknout řádky se jménem Bob
# + Bob a Klára

df["Name"] == "Bob"
# Out:
# A    False
# B     True
# C    False
# D    False
# Name: Name, dtype: bool

# %%
df.loc[  df["Name"] == "Bob"  ]
# Out:
#   Name  Age  English    Place  Score
# B  Bob   10    False  Smíchov    200

# %%
df["Name"]
# Out:
# A     Alan
# B      Bob
# C    Clara
# D     Dave
# Name: Name, dtype: object

# %%
df["Name"].isin( ["Bob", "Clara"] )
# Out:
# A    False
# B     True
# C     True
# D    False
# Name: Name, dtype: bool

# %%
df.loc[  df["Name"].isin(["Bob", "Clara"])  ]
# Out:
#     Name  Age  English       Place  Score
# B    Bob   10    False     Smíchov    200
# C  Clara   68    False  Holešovice    150

# %%
# Vytvoř nový sloupec Old který bude True pokud Age > 60

df["Old"] = df["Age"] > 60

df
# Out:
#     Name  Age  English       Place  Score    Old
# A   Alan   21     True     Dejvice    100  False
# B    Bob   10    False     Smíchov    200  False
# C  Clara   68    False  Holešovice    150   True
# D   Dave   13     True    Barandov     50  False

# %%
# Přidej nový řádek s daty ["Eve", 18, True, "Řepy", 250, False]

len(df)
# Out:
# 4

# %%
df.loc[len(df)] = ["Eve", 18, True, "Řepy", 250, False]
df
# Out:
#     Name  Age  English       Place  Score    Old
# A   Alan   21     True     Dejvice    100  False
# B    Bob   10    False     Smíchov    200  False
# C  Clara   68    False  Holešovice    150   True
# D   Dave   13     True    Barandov     50  False
# 4    Eve   18     True        Řepy    250  False

# %%
# Pomocí concat (Tohle je lepší)

new_row = pd.DataFrame({
    "Name": ["Frank"],
    "Age": [45],
    "English": [False],
    "Place": ["Břevnov"],
    "Score": [150],
    "Old": [False]
})

new_row
# Out:
#     Name  Age  English    Place  Score    Old
# 0  Frank   45    False  Břevnov    150  False

# %%
df = pd.concat([df, new_row])
df
# Out:
#     Name  Age  English       Place  Score    Old
# A   Alan   21     True     Dejvice    100  False
# B    Bob   10    False     Smíchov    200  False
# C  Clara   68    False  Holešovice    150   True
# D   Dave   13     True    Barandov     50  False
# 4    Eve   18     True        Řepy    250  False
# 0  Frank   45    False     Břevnov    150  False

# %%
# Vytvořte si DataFrame o alespoň 3 sloupcích
# + použijte na něj 3 různé filtry ( pomocí .loc .iloc nebo [] )
